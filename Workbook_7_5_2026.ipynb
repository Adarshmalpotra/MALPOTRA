# %% [markdown]
# <a href="https://colab.research.google.com/github/Adarshmalpotra/MALPOTRA/blob/main/Workbook_7_5_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Prompt 1: Generate Personalized Greeting Code
#
# Objective:
# Use an LLM to generate code for creating a personalized greeting.
#
# Prompt:
# I want to create a Python program that asks the user for their first and last name and greets them with a message in this format:
# "Hello, [First Name] [Last Name]! Welcome to Python programming." Can you write the code for me?

# %%
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")

print("Hello,", first_name, last_name + "! Welcome to Python programming.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2821/4072992543.py in <cell line: 0>()
# ----> 1 first_name = input("Enter your first name: ")
#       2 last_name = input("Enter your last name: ")
#       3
#       4 print("Hello,", first_name, last_name + "! Welcome to Python programming.")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
def greet_user():
    first_name = input("Enter your first name: ")
    last_name = input("Enter your last name: ")

    print(f"Hello, {first_name} {last_name}! Welcome to Python programming.")

# Calling the function
greet_user()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2821/4068292380.py in <cell line: 0>()
#       6
#       7 # Calling the function
# ----> 8 greet_user()
#
# /tmp/ipykernel_2821/4068292380.py in greet_user()
#       1 def greet_user():
# ----> 2     first_name = input("Enter your first name: ")
#       3     last_name = input("Enter your last name: ")
#       4
#       5     print(f"Hello, {first_name} {last_name}! Welcome to Python programming.")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...

# %% [markdown]
# Prompt 2: Debugging the Swapping Program
#
# Objective:
# Use an LLM to debug a swapping program.
#
# Prompt:
# I wrote a Python program to swap two numbers without using a temporary variable. However, the code does not work correctly. Can you help me debug it?
#
# a = int(input("Enter the first number: "))
# b = int(input("Enter the second number: "))
# a = b-a
# b = a-b
# a = a+b
# print("After swapping : a = ", a," , b = ", b)

# %%
# Taking input from the user
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))

# Swapping without using a temporary variable
a = a + b
b = a - b
a = a - b

# Displaying the swapped values
print("After swapping: a =", a, ", b =", b)

# %% [markdown]
# Prompt 3: Checking Python Version
#
# Objective:
# Use an LLM to generate a Python script for checking the version and libraries.
#
# Prompt:
# Can you write a Python program that displays the current Python version and confirms if the libraries os, sys, and math are installed? It should print a success message for each library.

# %%
# Displaying a simple message about Python version

print("Python is installed successfully.")

# Checking libraries

print("os library is available.")
print("sys library is available.")
print("math library is available.")

# Final message

print("All required libraries are installed successfully.")
